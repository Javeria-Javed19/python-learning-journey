# %% [markdown]
# <<<<<<<_PYTHON ASSIGNMENT 02_>>>>>>>

# %% [markdown]
#       ARITHMETIC OPERATORS

# %% [markdown]
# Q#O1:Write a Python program to add two numbers and print their result.

# %%
p = 23
q = 54
sum = p+q
print(sum)
# Out:
# 77

# %% [markdown]
# Q#02:Write a PYTHON program to find a remainder when One numer is divided by another.

# %%
a = 10
b = 5
remainder=a%b
print("Remainder:",remainder)
# Out:
# Remainder: 0

# %% [markdown]
# Q#03:Write a program to calculate square of a number using power operator.

# %%
num = 9
square = num ** 2
print("Square of a number:",square)
# Out:
# Square of a number: 81

# %% [markdown]
#            ASSIGNMENT OPERATORS

# %% [markdown]
# Q#04:Write a program that assign a value to a variable and then increase it by 5 using an assignment operator.

# %%
y = 6
y += 5
print("updated value:",y)
# Out:
# updated value: 11

# %% [markdown]
# Q#05:Write a program that multiplies a varaible by 2 using an assignment operator.

# %%
t = 19
t *= 2
print("RESULT:",t)
# Out:
# RESULT: 38

# %% [markdown]
# Q#06:Write a program that subtract 10 from a variable using an assignment operator.

# %%
k = 56
k -= 10
print("RESULT:",k)
# Out:
# RESULT: 46

# %% [markdown]
#         COMPARISON OPERATORS

# %% [markdown]
# Q#07:Write a program to check whether two numbers are equal or not.

# %%
a = 89
b = 79
print(a==b)
# Out:
# False

# %% [markdown]
# Q#08:Write a program to check if one number is greater than another.

# %%
x = 97
y = 67
print(x > y)
# Out:
# True

# %% [markdown]
# Q#09:Write a program to compare two numbers and print whether the first number is less than or equal to the second number.

# %%
a = 6
b = 3
print(a <= b)
# Out:
# False

# %% [markdown]
#      LOGICAL OPERATORS

# %% [markdown]
# Q#10:Write a program to check if a number is greater than 5 and less than 20.

# %%
num = 19
print(num > 5 and num <20)
# Out:
# True

# %% [markdown]
# Q#11:Write a program that checks if a number is less than 10 or greater than 50.

# %%
num = 63
print(num < 10 or num > 50)
# Out:
# True

# %% [markdown]
# Q#12:Write a program that uses NOT operator to reverse a condition.

# %%
num = 45
print(not (num > 40))
# Out:
# False

# %% [markdown]
#        MEMBERSHIP OPERATORS

# %% [markdown]
# Q#13:Write a program to check if a number exist in a list.

# %%
list = [ 1,3,6,7,8 ,9 ,4]
print( 3 in list)
# Out:
# True

# %% [markdown]
# Q#14:Write a program to check if a word exist in given string.

# %%
string = "BE THE TYPE OF PERSON YOU WANT TO MEET"
print( "PERSON" in string)
# Out:
# True

# %% [markdown]
# Q#15:Write a program to check whether a value is not present in tuple.

# %%
tuple = [ 45 , 56 ,78 ,90,56,18,45]
print( 19 not in tuple)
# Out:
# True

# %% [markdown]
#         END OF ASSIGNMENT 02
