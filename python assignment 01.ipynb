# %% [markdown]
# #PYTHON ASSIGNMENT 01:VARIABLES AND BASIC DATA TYPES

# %% [markdown]
# Q01:What is variable in Python?Write the syntax to create a variable and give one example.

# %%
# A variable is a container for storing data values.
# Syntax: variable_name=value
name="JAVERIA"
print(name)
# Out:
# JAVERIA

# %% [markdown]
# Q02:Rules of Variable  naming?

# %%
#RULES
# 1.Must start with a letter or underscore.
# 2.Cannot start with a number.
# 3.Only alphanumeric characters and undserscpres allowed(A-z,0-9,_).
my_var = 10     #Correct
# 1var = 5      #Incorrect(starts with a number)

# %% [markdown]
# Q03:DATATYPES
# INTEGERS!

# %%
#Integers(Whole numbers)
age=25

# %% [markdown]
# Q04:DATA TYPES FLOAT!

# %%
#Float (Decimal value)
price=99.9

# %% [markdown]
# Q05:DATA TYPES STRINGS!

# %%
# Two ways : Sinle qoutes or Double qoutes
city='Karachi'
country="Pakistan"

# %% [markdown]
# Q06:DATA TYPES BOOLEAN!

# %%
# A boolean represents  logical values.
# Possible Values:TRUE OR FALSE
is_student=True

# %% [markdown]
# Q07:type() Function!

# %%
# The type() function is used to check the data type of a variable.
x = 10
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# Q08: input() Function!

# %%
# THE input() function is used to take input from user.
# DEFAULT DATA TYPE:String
name = input("Enter your name:")

# %% [markdown]
# Q09:Typecasting!

# %%
# Type Casting means converting one data type into another.
# Example: String into Integer
num = "25"
num = int(num)

# %% [markdown]
# Q10:PROGRAM-BASED QUESTION!

# %%
# Program to take a number from user and print its data type.
num = input("ENTER A NUMBER:")
print(type(num))
# Out:
# <class 'str'>
